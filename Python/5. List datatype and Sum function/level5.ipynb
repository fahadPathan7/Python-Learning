# %% [markdown]
# ## Level 5 The List Data Type and the Sum Function

# %% [markdown]
# ---

# %% [markdown]
# ### list --->

# %%
# list is a collection of data
salary = [10, 20, 56]
total_salary = sum(salary) # it will sum the list data
print(total_salary)
print(type(salary))
# Out:
# 86
# <class 'list'>

# %% [markdown]
# #### exercise: <br>
# ![image.png](attachment:95c415f5-dc98-4817-8140-df79c6c7d819.png)

# %%
shopping_list = ["Milk", "Eggs", "Bread", "Bananas"]
shopping_list.append("Apples")
shopping_list.remove("Bread")

def show_list(shopping_items):
    print(shopping_items)

def total_items(shopping_items):
    print(len(shopping_items))

show_list(shopping_list)
total_items(shopping_list)
# Out:
# ['Milk', 'Eggs', 'Bananas', 'Apples']
# 4

# %% [markdown]
# ---
